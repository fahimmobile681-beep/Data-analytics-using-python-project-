# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimmobile681-beep/Data-analytics-using-python-project-/blob/main/day1_to_day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1=int(input("Enter mark1:"))

Mark2=int(input("Enter mark2:"))

Mark3=int(input("Enter mark3:"))

Total=Mark1+Mark2+Mark3

Average=Total/3

print("Total:", Total);

print("average:", Average);

if Average>=50:

 print("pass")

else:

 print("fail")
# Out:
# Enter mark1:30
# Enter mark2:40
# Enter mark3:50
# Total: 120
# average: 40.0
# fail

# %%
def greet (name):

 print("welcome" ,name)

greet("student")
# Out:
# welcome student

# %%
try:
   num= int(input("Enter Number:"))
   print(num)

except:
   print("Invalid Input")
# Out:
# Enter Number:123
# 123

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr[0])
print(arr[2])
print(arr[4])
# Out:
# 10
# 30
# 50

# %%
import pandas as pd

data = pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={
'Name': ['John','Mary','Bob', 'Alice'],
'sales': [500,800,700, None]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  sales
# 0   John  500.0
# 1   Mary  800.0
# 2    Bob  700.0
# 3  Alice    NaN

# %%
import pandas as pd

data={
'emp_nm': ['Abi', 'Athi'],
'emp_sal': [40000,50000],
}

df = pd.DataFrame(data)

df.rename(

columns={'emp_nm': 'Employee Name', 'emp_sal': 'Employee Salary'},
inplace=True,
)
print(df)
# Out:
#   Employee Name  Employee Salary
# 0           Abi            40000
# 1          Athi            50000

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb","Mar", "Apr", "May"]

sales = [10000, 12000,15000, 13000, 18000]

plt.plot(months, sales)
plt.title("Monthly Salea")

plt.xlabel("Months")
plt.ylabel("Sales Amount")

plt.show()

# %%
import matplotlib.pyplot as plt

expenses=[12000,13000,5000,23000]
categories=["Rent", "Travel","Food","Business"]

plt.pie(expenses,labels=categories,autopct="%1.1f%%")
plt.show()
