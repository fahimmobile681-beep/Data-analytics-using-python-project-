# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimmobile681-beep/Data-analytics-using-python-project-/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df[['Age', 'Attrition', 'Department']].head()
df.head(2)

import pandas as pd
pd.set_option('display.max_columns', 5)
pd.set_option('display.max_rows', 10)
df.head()

df.head(5)
import pandas as pd
pd.set_option('display.max_rows',10)

null_counts=df.isnull().sum()
null_counts[null_counts>0]

from IPython.display import clear_output
clear_output()
print("process complete")

df = df.drop_duplicates()

df['Attrition'] =df['Attrition'].map({'Yes':1, 'No':0})

def salary_category(x):
    if x < 3000:
        return "Low"
    elif x < 7000:
        return "Medium"
    else:
        return "High"

df['SalaryCategory']=df['MonthlyIncome'].apply(salary_category)

df['Experience'] = df['YearsAtCompany']

attrition_rate = df['Attrition'].mean() * 100

print("Overall Attrition Rate:", attrition_rate)

dept_attrition = df.groupby('Department') ['Attrition'].mean() * 100
print(dept_attrition)

salary_attrition = df.groupby('SalaryCategory') ['Attrition'].mean() * 100
print(salary_attrition)

exp_attrition = df.groupby('Experience') ['Attrition'].mean() * 100
print(exp_attrition.head())

corr = df.corr(numeric_only=True)
plt. figure(figsize=(10,6))
sns.heatmap(corr, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

df['Attrition'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Attrition Distribution")
plt.ylabel("")
plt.show()

dept_attrition.plot(kind='bar')
plt.title("Attrition by Department")
plt.ylabel("Percentage")
plt.show()
salary_attrition.plot(kind='bar')
plt.title("Attrition by Salary")
plt.ylabel("Percentage")
plt.show()

exp_attrition.plot(kind='line', marker='o')

plt.title("Attrition by Experience")

plt.xlabel("Years")

plt.ylabel("Percentage")

plt.show()
# Out:
# process complete
# Overall Attrition Rate: 16.122448979591837
# Department
# Human Resources           19.047619
# Research & Development    13.839750
# Sales                     20.627803
# Name: Attrition, dtype: float64
# SalaryCategory
# High      10.804598
# Low       28.607595
# Medium    12.031250
# Name: Attrition, dtype: float64
# Experience
# 0    36.363636
# 1    34.502924
# 2    21.259843
# 3    15.625000
# 4    17.272727
# Name: Attrition, dtype: float64
