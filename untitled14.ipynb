# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimmobile681-beep/Data-analytics-using-python-project-/blob/main/untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = { 'Age': [30, 25, 35, 40, 28],
    'Attrition': ['Yes', 'No', 'Yes', 'No', 'No'],
    'BusinessTravel': ['Travel_Rarely', 'Travel_Frequently', 'Travel_Rarely', 'Travel_Frequently', 'Travel_Rarely'],
    'Department': ['Sales', 'Research & Development', 'Research & Development', 'Research & Development', 'Research & Development'],
    'EducationField': ['Life Sciences', 'Life Sciences', 'Other', 'Life Sciences', 'Medical']
}

df = pd.DataFrame(data)
df.head()

pd.set_option('display.max_columns', 5)
pd.set_option('display.max_rows', 10)

df[['Age', 'Attrition', 'Department']].head()
df.head()
from google.colab import data_table
data_table.enable_dataframe_formatter()
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department EducationField
# 0   30       Yes      Travel_Rarely                   Sales  Life Sciences
# 1   25        No  Travel_Frequently  Research & Development  Life Sciences
# 2   35       Yes      Travel_Rarely  Research & Development          Other
# 3   40        No  Travel_Frequently  Research & Development  Life Sciences
# 4   28        No      Travel_Rarely  Research & Development        Medical
